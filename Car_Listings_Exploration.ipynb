# %% [markdown]
# Using Pandas and Numpy, a dataset will be cleaned and analyzed.  The dataset is data about used cars on _eBay Kleinanzeigen_ which is part of eBay for Germany.  The dataset is a modified subset of a set that originally appeared on Kaggle.

# %%
import pandas as pd
import numpy as np

# %%
autos = pd.read_csv('autos.csv', encoding='Latin-1')

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %% [markdown]
# It looks like there are 5 columns with null values.  The column with the most null values is notRepairedDamage.  Perhaps the sellers did not want to disclose the state of damage of their cars.
# There are 50,000 rows in this modified dataset and 20 columns.  Five of the columns hold integers and the other 15 are string columns which we may need to do some preprocessing on.

# %%
def camel_case_to_snake_case(string):
    result_list = []
    for c in string:
        if c.isupper():
            result_list.append('_')
            result_list.append(c.lower())
        else:
            result_list.append(c)
    return ''.join(result_list)

# %%
columns_to_rename = {
    'yearOfRegistration': 'registration_year',
    'monthOfRegistration': 'registration_month',
    'notRepairedDamage': 'unrepaired_damage',
    'dateCreated': 'ad_created'
}

# %%
autos.rename(columns_to_rename, inplace=True, axis=1)
autos.columns = map(lambda x: camel_case_to_snake_case(x), autos.columns)

# %%
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_p_s', 'model',
#        'odometer', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %% [markdown]
# Changed the column names so they are all camel case and easy to remember and reference.  Converting to camel case is useful because then you can reference each column as a field of the dataframe (ie `autos.last_seen`) and it fits the general Python coding standards (PEP8).

# %%
autos.describe()
# Out:
#        registration_year     power_p_s  registration_month  nr_of_pictures  \
# count       50000.000000  50000.000000        50000.000000         50000.0
# mean         2005.073280    116.355920            5.723360             0.0
# std           105.712813    209.216627            3.711984             0.0
# min          1000.000000      0.000000            0.000000             0.0
# 25%          1999.000000     70.000000            3.000000             0.0
# 50%          2003.000000    105.000000            6.000000             0.0
# 75%          2008.000000    150.000000            9.000000             0.0
# max          9999.000000  17700.000000           12.000000             0.0
#
#         postal_code
# count  50000.000000
# mean   50813.627300
# std    25779.747957
# min     1067.000000
# 25%    30451.000000
# 50%    49577.000000
# 75%    71540.000000
# max    99998.000000

# %% [markdown]
# From a simple describe call, we can see that nr_of_pictures is entirely zeros so should probably be dropped.  There are a couple of suspicious values that show up in this table.  First, the minimum value of registration year shows as 1000, which must be wrong.  Also the max is greater than the current year so must also be wrong.  Also there are thirteen values of registration month if the minimum is 0 and the max is 12 and all values are used in between.  So it is possible that 0 is just being used as a "don't know" value there.

# %% [markdown]
# Additionally, price and odometer do not have numeric types, so these should be investigated and possibly converted into numeric types to enhance their usefulness.

# %%
autos.registration_year.value_counts()
# Out:
# 2000    3354
# 2005    3015
# 1999    3000
# 2004    2737
# 2003    2727
# 2006    2708
# 2001    2703
# 2002    2533
# 1998    2453
# 2007    2304
# 2008    2231
# 2009    2098
# 1997    2028
# 2011    1634
# 2010    1597
# 2017    1453
# 1996    1444
# 2012    1323
# 2016    1316
# 1995    1313
# 2013     806
# 2014     666
# 1994     660
# 2018     492
# 1993     445
# 2015     399
# 1990     395
# 1992     391
# 1991     356
# 1989     181
#         ...
# 1950       3
# 1955       2
# 9000       2
# 1954       2
# 1800       2
# 1957       2
# 1941       2
# 1951       2
# 1934       2
# 4100       1
# 4800       1
# 1953       1
# 1111       1
# 1927       1
# 6200       1
# 4500       1
# 1943       1
# 5911       1
# 1939       1
# 1938       1
# 2800       1
# 8888       1
# 1000       1
# 1500       1
# 1948       1
# 1931       1
# 1929       1
# 1001       1
# 9996       1
# 1952       1
# Name: registration_year, Length: 97, dtype: int64

# %%
autos.registration_month.value_counts()
# Out:
# 0     5075
# 3     5071
# 6     4368
# 5     4107
# 4     4102
# 7     3949
# 10    3651
# 12    3447
# 9     3389
# 11    3360
# 1     3282
# 8     3191
# 2     3008
# Name: registration_month, dtype: int64

# %% [markdown]
# It appears that the registration year has many incorrect values.  Either the column should be disregarded, or the values that lie outside of a certain range should be thrown out.
# As far as registration month, 0 is the only weird value so should probably be treated as missing data.

# %%
autos.price = autos.price.str.replace('$', '').str.replace(',', '').astype(int)

# %%
autos.odometer = autos.odometer.str.replace(',','').str.replace('km','').astype(int)

# %%
autos.rename({'odometer': 'odometer_km'}, axis=1, inplace=True)

# %%
autos.odometer_km.unique().shape
# Out:
# (13,)

# %%
autos.price.unique().shape
# Out:
# (2357,)

# %%
autos.odometer_km.describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
autos.price.describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
autos.odometer_km.value_counts()
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 5000        967
# 40000       819
# 30000       789
# 20000       784
# 10000       264
# Name: odometer_km, dtype: int64

# %%
autos.price.value_counts().sort_index(ascending=False)
# Out:
# 99999999       1
# 27322222       1
# 12345678       3
# 11111111       2
# 10000000       1
# 3890000        1
# 1300000        1
# 1234566        1
# 999999         2
# 999990         1
# 350000         1
# 345000         1
# 299000         1
# 295000         1
# 265000         1
# 259000         1
# 250000         1
# 220000         1
# 198000         1
# 197000         1
# 194000         1
# 190000         1
# 180000         1
# 175000         1
# 169999         1
# 169000         1
# 163991         1
# 163500         1
# 155000         1
# 151990         1
#             ...
# 66             1
# 65             5
# 60             9
# 59             1
# 55             2
# 50            49
# 49             4
# 47             1
# 45             4
# 40             6
# 35             1
# 30             7
# 29             1
# 25             5
# 20             4
# 18             1
# 17             3
# 15             2
# 14             1
# 13             2
# 12             3
# ...

# %%
autos = autos[autos.price.between(0, 350000)]

# %% [markdown]
# I am removing rows where the price is 0 because that is not an auto that is "for sale".  I am also setting the upper bound as 351,000 because there is a large gap between that number and the numbers above that, whereas it is fairly continuous before that.

# %%
autos.odometer_km.value_counts().sort_index(ascending=False)
# Out:
# 150000    32416
# 125000     5169
# 100000     2168
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1025
# 40000       818
# 30000       789
# 20000       784
# 10000       264
# 5000        966
# Name: odometer_km, dtype: int64

# %% [markdown]
# Let's figure out what to do with that registration year column.

# %%
autos.registration_year.value_counts().sort_index(ascending=True)
# Out:
# 1000       1
# 1001       1
# 1111       1
# 1500       1
# 1800       2
# 1910       9
# 1927       1
# 1929       1
# 1931       1
# 1934       2
# 1937       4
# 1938       1
# 1939       1
# 1941       2
# 1943       1
# 1948       1
# 1950       3
# 1951       2
# 1952       1
# 1953       1
# 1954       2
# 1955       2
# 1956       5
# 1957       2
# 1958       4
# 1959       7
# 1960      33
# 1961       6
# 1962       4
# 1963       9
#         ...
# 2001    2702
# 2002    2533
# 2003    2727
# 2004    2737
# 2005    3015
# 2006    2707
# 2007    2304
# 2008    2231
# 2009    2097
# 2010    1597
# 2011    1634
# 2012    1323
# 2013     806
# 2014     665
# 2015     399
# 2016    1316
# 2017    1452
# 2018     491
# 2019       3
# 2800       1
# 4100       1
# 4500       1
# 4800       1
# 5000       4
# 5911       1
# 6200       1
# 8888       1
# 9000       2
# 9996       1
# 9999       4
# Name: registration_year, Length: 97, dtype: int64

# %% [markdown]
# Anything greater than 2016 has to be wrong since that is when this dataset was gathered.  That removes about 2000 rows, but are obviously wrong.  Additionally, anything before 1900 is probably wrong since the automobile was invented around the 1880s.  So that's another 6 rows with a questionable registration year value.  Time to remove those rows.

# %%
autos = autos[autos.registration_year.between(1900,2016)]

# %%
autos.registration_year.value_counts().sort_index(ascending=True)
# Out:
# 1910       9
# 1927       1
# 1929       1
# 1931       1
# 1934       2
# 1937       4
# 1938       1
# 1939       1
# 1941       2
# 1943       1
# 1948       1
# 1950       3
# 1951       2
# 1952       1
# 1953       1
# 1954       2
# 1955       2
# 1956       5
# 1957       2
# 1958       4
# 1959       7
# 1960      33
# 1961       6
# 1962       4
# 1963       9
# 1964      12
# 1965      17
# 1966      22
# 1967      27
# 1968      26
#         ...
# 1987      75
# 1988     142
# 1989     181
# 1990     395
# 1991     356
# 1992     390
# 1993     445
# 1994     660
# 1995    1312
# 1996    1444
# 1997    2028
# 1998    2453
# 1999    2998
# 2000    3354
# 2001    2702
# 2002    2533
# 2003    2727
# 2004    2737
# 2005    3015
# 2006    2707
# 2007    2304
# 2008    2231
# 2009    2097
# 2010    1597
# 2011    1634
# 2012    1323
# 2013     806
# 2014     665
# 2015     399
# 2016    1316
# Name: registration_year, Length: 78, dtype: int64

# %% [markdown]
# The registration year looks reasonable now.  Also, it appears that most of the entries have recent registration years with fewer listings as the registration year gets older, as might be expected.

# %%
freqs = autos.brand.value_counts(normalize=True)
#lets select the top 20 makes
companies_of_interest = freqs.head(20).index

# %% [markdown]
# I'm going to find the mean price and mileage of the top 20 car brands (as ordered by ad frequency)

# %%
rows_with_brand = autos.loc[autos.brand.isin(companies_of_interest), ['brand', 'price', 'odometer_km']]
mean_prices = rows_with_brand.groupby('brand').agg({'price': 'mean', 'odometer_km': 'mean'}, index=False)
mean_prices
# Out:
#                   odometer_km         price
# brand
# audi            129287.780188   9093.650036
# bmw             132431.383684   8102.536248
# citroen         119580.838323   3699.935629
# fiat            116553.945250   2711.801127
# ford            124068.656716   3652.095224
# hyundai         106511.627907   5308.539112
# mazda           124745.529574   4010.771664
# mercedes_benz   130856.082114   8485.239572
# mini             88602.409639  10460.012048
# nissan          118572.413793   4664.891034
# opel            129223.142087   2876.716404
# peugeot         127136.812412   3039.468265
# renault         128183.817062   2395.416447
# seat            121563.573883   4296.492554
# skoda           110954.545455   6334.919481
# smart            99595.808383   3542.706587
# sonstige_autos   87466.539197  10805.078394
# toyota          115709.515860   5115.333890
# volkswagen      128724.104075   5231.081983
# volvo           138355.855856   4757.108108

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(mean_prices.price, mean_prices.odometer_km)
plt.xlabel('Mean Price')
plt.ylabel('Mean Odometer KM')
plt.show()

# %% [markdown]
# It appears that generally, for each brand there is a negative relationship between odometer reading and price.  This makes sense because if a car has been driven more, it is generally more apt to break down, which means that the market value is lower.
